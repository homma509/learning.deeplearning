# %%
def add(a, b):
    c = a + b
    return c

print(add(3, 4))
# Out:
# 7

# %%
def add(a, b=4):
    c = a + b
    return c

print(add(3))
# Out:
# 7

# %%
def add(a, b, c):
    d = a + b + c
    return d
    
e = (1, 2, 3)
print(add(*e))
# Out:
# 6

# %%
a = 123

def showNum():
    b = 456
    print(a, b)
    
showNum()
# Out:
# 123 456

# %%
a = 123

def setLocal():
    a = 456
    print("Local: ", a)
    
setLocal()
print("Global: ", a)
# Out:
# Local:  456
# Global:  123

# %%
a = 123

def setGlobal():
    global a
    a = 456
    print("Global: ", a)
    
setGlobal()
print("Global: ", a)
# Out:
# Global:  456
# Global:  456

# %%
class Calc:
    def __init__(self, a):
        self.a = a
    
    def add(self, b):
        print(self.a + b)
        
    def multiply(self, b):
        print(self.a * b)

# %%
calc = Calc(3)
calc.add(4)
calc.multiply(4)
# Out:
# 7
# 12

# %%
class CalcPlus(Calc):
    def subtract(self, b):
        print(self.a - b)
        
    def divide(self, b):
        print(self.a / b)

# %%
calc_plus = CalcPlus(3)
calc_plus.add(4)
calc_plus.multiply(4)
calc_plus.subtract(4)
calc_plus.divide(4)
# Out:
# 7
# 12
# -1
# 0.75
