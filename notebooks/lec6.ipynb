# %%
a = 123

# %%
a = 123
b = 123.456
c = "Hello World!"
d = True
e = [1, 2, 3]

# %%
a = True; b = False
print(a+b)
# Out:
# 1

# %%
1.2e5
1.2e-5
# Out:
# 1.2e-05

# %%
a = 3; b = 4
c = a + b
print(c)
d = a < b
print(d)
e = 3 < 4 and 4 < 5
print(e)
# Out:
# 7
# True
# True

# %%
a = [1, 2, 3, 4, 5]

b = a[2]
print(b)

a.append(6)
print(a)

a[2] = 7
print(a)
# Out:
# 3
# [1, 2, 3, 4, 5, 6]
# [1, 2, 7, 4, 5, 6]

# %%
a = (1, 2, 3, 4, 5)
b = a[2]
print(b)
# Out:
# 3

# %%
(3,)
# Out:
# (3,)

# %%
a = [1, 2, 3]
a1, a2, a3 = a
print(a1, a2, a3)

b = (4, 5, 6)
b1, b2, b3 = b
print(b1, b2, b3)
# Out:
# 1 2 3
# 4 5 6

# %%
a = 7
if a < 12:
    print("Good morning!")
elif a < 17:
    print("Good afternoon!")
elif a < 21:
    print("Good evening!")
else:
    print("Good night!")
# Out:
# Good morning!

# %%
for a in [4, 7, 10]:
    print(a)
    
for a in range(3):
    print(a)
# Out:
# 4
# 7
# 10
# 0
# 1
# 2
